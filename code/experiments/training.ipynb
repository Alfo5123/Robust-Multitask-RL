# %%
# %matplotlib
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')
from envs.gridworld_env import GridworldEnv
from utils import play_game
# Out:
# Using matplotlib backend: Qt5Agg
# Warning: Cannot change to a different GUI toolkit: notebook. Using qt instead.

# %%
sys.path.append('../dqn')
import trainingDQN
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
agent_dqn, dqn_rewards, dqn_durations = trainingDQN.trainDQN(file_name="env4",
                    env=GridworldEnv(4),
                    batch_size=128,
                    gamma=0.999,
                    eps_start=0.9,
                    eps_end=0.05,
                    eps_decay=1000,
                    is_plot=False,
                    num_episodes=500,
                    max_num_steps_per_episode=1000,
                    learning_rate=0.0001,
                    memory_replay_size=10000,
                )
# Out:
# Cur episode: 480 steps done: 14777 exploration factor: 0.05000032497456166
# Cur episode: 481 steps done: 14790 exploration factor: 0.050000320777234104
# Cur episode: 482 steps done: 14803 exploration factor: 0.050000316634118656
# Cur episode: 483 steps done: 14820 exploration factor: 0.0500003112968341
# Cur episode: 484 steps done: 14833 exploration factor: 0.05000030727616622
# Cur episode: 485 steps done: 14846 exploration factor: 0.050000303307428745
# Cur episode: 486 steps done: 14859 exploration factor: 0.05000029938995095
# Cur episode: 487 steps done: 14875 exploration factor: 0.05000029463783008
# Cur episode: 488 steps done: 14888 exploration factor: 0.05000029083232765
# Cur episode: 489 steps done: 14903 exploration factor: 0.05000028650239839
# Cur episode: 490 steps done: 14916 exploration factor: 0.05000028280197209
# Cur episode: 491 steps done: 14930 exploration factor: 0.05000027887033019
# Cur episode: 492 steps done: 14943 exploration factor: 0.05000027526847867
# Cur episode: 493 steps done: 14959 exploration factor: 0.050000270899230204
# Cur episode: 494 steps done: 14984 exploration factor: 0.05000026421070438
# Cur episode: 495 steps done: 14997 exploration factor: 0.05000026079819459
# Cur episode: 496 steps done: 15010 exploration factor: 0.050000257429760324
# Cur episode: 497 steps done: 15023 exploration factor: 0.0500002541048323
# Cur episode: 498 steps done: 15036 exploration factor: 0.0500002508228486
# Cur episode: 499 steps done: 15055 exploration factor: 0.05000024610220262
# Complete

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 2 layers
plt.plot(dqn_rewards)
plt.show()
plt.plot(dqn_durations)
plt.show()

# %%
# 3 layers with leaky relu
plt.plot(dqn_rewards)
plt.show()
plt.plot(dqn_durations)
plt.show()

# %%
plt.plot(dqn_rewards)
plt.show()
plt.plot(dqn_durations)
plt.show()

# %%
play_game(GridworldEnv(4), agent_dqn)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-8f00f296637a> in <module>()
# ----> 1 play_game(GridworldEnv(4), agent_dqn)
#
# ~/skoltech/Robust-Multitask-RL/code/utils.py in play_game(env, agent, max_steps_num)
#      24         plt.draw()
#      25         plt.pause(0.01)
# ---> 26         action = agent(Variable(state, volatile=True).type(FloatTensor
#      27                             )).data.max(1)[1].view(1, 1)
#      28         _, reward, done, _ = env.step(action[0, 0])
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/skoltech/Robust-Multitask-RL/code/dqn/network.py in forward(self, x)
#      33         x = F.leaky_relu(self.bn2(self.conv2(x)))
#      34         # x = F.leaky_relu(self.bn3(self.conv3(x)))
# ---> 35         return self.head(x.view(x.size(0), -1))
#      36
#      37 # class DQN(nn.Module):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     833     if input.dim() == 2 and bias is not None:
#     834         # fused op is marginally faster
# --> 835         return torch.addmm(bias, input, weight.t())
#     836
#     837     output = input.matmul(weight.t())
#
# RuntimeError: size mismatch, m1: [1 x 420], m2: [200 x 5] at /opt/conda/conda-bld/pytorch-cpu_1518282373170/work/torch/lib/TH/generic/THTensorMath.c:1434

# %%
sys.path.remove("../dqn")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-f56696a32341> in <module>()
# ----> 1 sys.path.remove("../dqn")
#
# ValueError: list.remove(x): x not in list

# %%
sys.path
# Out:
# ['',
#  '/home/nastya/anaconda3/lib/python36.zip',
#  '/home/nastya/anaconda3/lib/python3.6',
#  '/home/nastya/anaconda3/lib/python3.6/lib-dynload',
#  '/home/nastya/anaconda3/lib/python3.6/site-packages',
#  '/home/nastya/gym',
#  '/home/nastya/anaconda3/lib/python3.6/site-packages/torchvision-0.2.0-py3.6.egg',
#  '/home/nastya/anaconda3/lib/python3.6/site-packages/IPython/extensions',
#  '/home/nastya/.ipython',
#  '../',
#  '../',
#  '../',
#  '../',
#  '../',
#  '../',
#  '../',
#  '../',
#  '../',
#  '../sql',
#  '../',
#  '../']

# %%
# %matplotlib
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')
from envs.gridworld_env import GridworldEnv
from utils import play_game

sys.path.append('../sql')
import trainingSQL
# Out:
# Using matplotlib backend: Qt5Agg
# Warning: Cannot change to a different GUI toolkit: notebook. Using qt instead.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
agent_sql, sql_rewards, sql_durations = trainingSQL.trainSQL(file_name="env4",
                                                            env=GridworldEnv(4),
                                                            batch_size=128,
                                                            gamma=0.99,
                                                            beta=10,
                                                            eps_start=1,
                                                            eps_end=0.05,
                                                            eps_decay=5,
                                                            is_plot=False,
                                                            num_episodes=500,
                                                            max_num_steps_per_episode=20000,
                                                            learning_rate=0.001,
                                                            memory_replay_size=10000,)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Cur episode: 0 steps done: 0 exploration factor: 1.0
# Cur episode: 1 steps done: 1356 exploration factor: 0.8277942154240827
# Cur episode: 2 steps done: 937 exploration factor: 0.6868040437338574
# Cur episode: 3 steps done: 1666 exploration factor: 0.5713710542893251
# Cur episode: 4 steps done: 1801 exploration factor: 0.4768625159113605
# Cur episode: 5 steps done: 1111 exploration factor: 0.3994854691128702
# Cur episode: 6 steps done: 2392 exploration factor: 0.336134501316592
# Cur episode: 7 steps done: 600 exploration factor: 0.2842671157445262
# Cur episode: 8 steps done: 3573 exploration factor: 0.24180169209492258
# Cur episode: 9 steps done: 1408 exploration factor: 0.20703394381050721
# Cur episode: 10 steps done: 5111 exploration factor: 0.17856851907478205
# Cur episode: 11 steps done: 826 exploration factor: 0.15526300044421718
# Cur episode: 12 steps done: 3058 exploration factor: 0.1361820556249419
# Cur episode: 13 steps done: 5499 exploration factor: 0.12055989930361719
# Cur episode: 14 steps done: 6971 exploration factor: 0.10776955949395708
# Cur episode: 15 steps done: 7923 exploration factor: 0.09729771494947075
# Cur episode: 16 steps done: 10292 exploration factor: 0.0887240937794479
# Cur episode: 17 steps done: 3210 exploration factor: 0.08170460646230979
# Cur episode: 18 steps done: 9084 exploration factor: 0.07595753632492794
# Cur episode: 19 steps done: 1891 exploration factor: 0.07125223326335732
# Cur episode: 20 steps done: 6231 exploration factor: 0.06739985694429747
# Cur episode: 21 steps done: 1937 exploration factor: 0.06424579797945382
# Cur episode: 22 steps done: 4709 exploration factor: 0.06166347290791502
# Cur episode: 23 steps done: 3296 exploration factor: 0.05954924395740191
# Cur episode: 24 steps done: 19999 exploration factor: 0.05781825969656903
# Cur episode: 25 steps done: 5004 exploration factor: 0.056401049649131195
# Cur episode: 26 steps done: 17630 exploration factor: 0.05524073619972274
# Cur episode: 27 steps done: 3190 exploration factor: 0.054290751895482034
# Cur episode: 28 steps done: 7553 exploration factor: 0.05351297053065879
# Cur episode: 29 steps done: 19999 exploration factor: 0.052876177008107025
# Cur episode: 30 steps done: 14363 exploration factor: 0.052354814567833044
# Cur episode: 31 steps done: 7771 exploration factor: 0.05192795910448095
# Cur episode: 32 steps done: 12499 exploration factor: 0.05157847940951524
# Cur episode: 33 steps done: 15083 exploration factor: 0.0512923496356705
# Cur episode: 34 steps done: 19999 exploration factor: 0.05105808639045257
# Cur episode: 35 steps done: 7846 exploration factor: 0.050866287867276795
# Cur episode: 36 steps done: 3364 exploration factor: 0.05070925651795785
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9a54892d7700> in <module>()
#      11                                                             max_num_steps_per_episode=20000,
#      12                                                             learning_rate=0.001,
# ---> 13                                                             memory_replay_size=10000,)
#
# ~/skoltech/Robust-Multitask-RL/code/sql/trainingSQL.py in trainSQL(file_name, env, batch_size, gamma, beta, eps_start, eps_end, eps_decay, is_plot, num_episodes, max_num_steps_per_episode, learning_rate, memory_replay_size)
#      81
#      82             # Perform one step of the optimization (on the target network)
# ---> 83             optimize_model(model, optimizer, memory, batch_size, gamma, beta)
#      84             if done or t + 1 >= max_num_steps_per_episode:
#      85                 episode_durations.append(t + 1)
#
# ~/skoltech/Robust-Multitask-RL/code/sql/network.py in optimize_model(model, optimizer, memory, BATCH_SIZE, GAMMA, BETA)
#     114     # Optimize the model
#     115     optimizer.zero_grad()
# --> 116     loss.backward()
#     117     for param in model.parameters():
#     118         param.grad.data.clamp_(-1, 1)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     165                 Variable.
#     166         """
# --> 167         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     168
#     169     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      97
#      98     Variable._execution_engine.run_backward(
# ---> 99         variables, grad_variables, retain_graph)
#     100
#     101
#
# KeyboardInterrupt:
